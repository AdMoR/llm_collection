# %%
# !pip install llama_index
# !pip install llama-index-utils-workflow
# !pip install llama-index-core
# !pip install llama-index-retrievers-bm25
# Out:
# Requirement already satisfied: llama_index in /home/amor/anaconda3/lib/python3.11/site-packages (0.12.5)
# Requirement already satisfied: llama-index-agent-openai<0.5.0,>=0.4.0 in /home/amor/anaconda3/lib/python3.11/site-packages (from llama_index) (0.4.0)
# Requirement already satisfied: llama-index-cli<0.5.0,>=0.4.0 in /home/amor/anaconda3/lib/python3.11/site-packages (from llama_index) (0.4.0)
# Requirement already satisfied: llama-index-core<0.13.0,>=0.12.5 in /home/amor/anaconda3/lib/python3.11/site-packages (from llama_index) (0.12.5)
# Requirement already satisfied: llama-index-embeddings-openai<0.4.0,>=0.3.0 in /home/amor/anaconda3/lib/python3.11/site-packages (from llama_index) (0.3.1)
# Requirement already satisfied: llama-index-indices-managed-llama-cloud>=0.4.0 in /home/amor/anaconda3/lib/python3.11/site-packages (from llama_index) (0.6.3)
# Requirement already satisfied: llama-index-legacy<0.10.0,>=0.9.48 in /home/amor/anaconda3/lib/python3.11/site-packages (from llama_index) (0.9.48.post4)
# Requirement already satisfied: llama-index-llms-openai<0.4.0,>=0.3.0 in /home/amor/anaconda3/lib/python3.11/site-packages (from llama_index) (0.3.10)
# Requirement already satisfied: llama-index-multi-modal-llms-openai<0.5.0,>=0.4.0 in /home/amor/anaconda3/lib/python3.11/site-packages (from llama_index) (0.4.0)
# Requirement already satisfied: llama-index-program-openai<0.4.0,>=0.3.0 in /home/amor/anaconda3/lib/python3.11/site-packages (from llama_index) (0.3.1)
# Requirement already satisfied: llama-index-question-gen-openai<0.4.0,>=0.3.0 in /home/amor/anaconda3/lib/python3.11/site-packages (from llama_index) (0.3.0)
# Requirement already satisfied: llama-index-readers-file<0.5.0,>=0.4.0 in /home/amor/anaconda3/lib/python3.11/site-packages (from llama_index) (0.4.1)
# Requirement already satisfied: llama-index-readers-llama-parse>=0.4.0 in /home/amor/anaconda3/lib/python3.11/site-packages (from llama_index) (0.4.0)
# Requirement already satisfied: nltk>3.8.1 in /home/amor/anaconda3/lib/python3.11/site-packages (from llama_index) (3.9.1)
# Requirement already satisfied: openai>=1.14.0 in /home/amor/anaconda3/lib/python3.11/site-packages (from llama-index-agent-openai<0.5.0,>=0.4.0->llama_index) (1.57.4)
# Requirement already satisfied: PyYAML>=6.0.1 in /home/amor/anaconda3/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.5->llama_index) (6.0.2)
# Requirement already satisfied: SQLAlchemy>=1.4.49 in /home/amor/anaconda3/lib/python3.11/site-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.13.0,>=0.12.5->llama_index) (2.0.25)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.6 in /home/amor/anaconda3/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.5->llama_index) (3.9.3)
# Requirement already satisfied: dataclasses-json in /home/amor/anaconda3/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.5->llama_index) (0.6.7)
# Requirement already satisfied: deprecated>=1.2.9.3 in /home/amor/anaconda3/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.5->llama_index) (1.2.15)
# Requirement already satisfied: dirtyjson<2.0.0,>=1.0.8 in /home/amor/anaconda3/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.5->llama_index) (1.0.8)
# Requirement already satisfied: filetype<2.0.0,>=1.2.0 in /home/amor/anaconda3/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.5->llama_index) (1.2.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /home/amor/anaconda3/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.5->llama_index) (2023.10.0)
# Requirement already satisfied: httpx in /home/amor/anaconda3/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.5->llama_index) (0.27.2)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in /home/amor/anaconda3/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.5->llama_index) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in /home/amor/anaconda3/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.5->llama_index) (3.1)
# Requirement already satisfied: numpy in /home/amor/anaconda3/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.5->llama_index) (1.26.4)
# Requirement already satisfied: pillow>=9.0.0 in /home/amor/anaconda3/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.5->llama_index) (9.5.0)
# Requirement already satisfied: pydantic>=2.8.0 in /home/amor/anaconda3/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.5->llama_index) (2.10.1)
# Requirement already satisfied: requests>=2.31.0 in /home/amor/anaconda3/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.5->llama_index) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.2.0 in /home/amor/anaconda3/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.5->llama_index) (8.5.0)
# Requirement already satisfied: tiktoken>=0.3.3 in /home/amor/anaconda3/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.5->llama_index) (0.8.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.66.1 in /home/amor/anaconda3/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.5->llama_index) (4.67.0)
# Requirement already satisfied: typing-extensions>=4.5.0 in /home/amor/anaconda3/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.5->llama_index) (4.12.2)
# Requirement already satisfied: typing-inspect>=0.8.0 in /home/amor/anaconda3/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.5->llama_index) (0.9.0)
# Requirement already satisfied: wrapt in /home/amor/anaconda3/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.5->llama_index) (1.14.1)
# Requirement already satisfied: llama-cloud>=0.1.5 in /home/amor/anaconda3/lib/python3.11/site-packages (from llama-index-indices-managed-llama-cloud>=0.4.0->llama_index) (0.1.6)
# Requirement already satisfied: pandas in /home/amor/anaconda3/lib/python3.11/site-packages (from llama-index-legacy<0.10.0,>=0.9.48->llama_index) (2.1.4)
# Requirement already satisfied: beautifulsoup4<5.0.0,>=4.12.3 in /home/amor/anaconda3/lib/python3.11/site-packages (from llama-index-readers-file<0.5.0,>=0.4.0->llama_index) (4.12.3)
# Requirement already satisfied: pypdf<6.0.0,>=5.1.0 in /home/amor/anaconda3/lib/python3.11/site-packages (from llama-index-readers-file<0.5.0,>=0.4.0->llama_index) (5.1.0)
# Requirement already satisfied: striprtf<0.0.27,>=0.0.26 in /home/amor/anaconda3/lib/python3.11/site-packages (from llama-index-readers-file<0.5.0,>=0.4.0->llama_index) (0.0.26)
# Requirement already satisfied: llama-parse>=0.5.0 in /home/amor/anaconda3/lib/python3.11/site-packages (from llama-index-readers-llama-parse>=0.4.0->llama_index) (0.5.17)
# Requirement already satisfied: click in /home/amor/anaconda3/lib/python3.11/site-packages (from nltk>3.8.1->llama_index) (8.1.7)
# Requirement already satisfied: joblib in /home/amor/anaconda3/lib/python3.11/site-packages (from nltk>3.8.1->llama_index) (1.2.0)
# Requirement already satisfied: regex>=2021.8.3 in /home/amor/anaconda3/lib/python3.11/site-packages (from nltk>3.8.1->llama_index) (2023.10.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/amor/anaconda3/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.5->llama_index) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in /home/amor/anaconda3/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.5->llama_index) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/amor/anaconda3/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.5->llama_index) (1.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/amor/anaconda3/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.5->llama_index) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /home/amor/anaconda3/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.5->llama_index) (1.9.3)
# Requirement already satisfied: soupsieve>1.2 in /home/amor/anaconda3/lib/python3.11/site-packages (from beautifulsoup4<5.0.0,>=4.12.3->llama-index-readers-file<0.5.0,>=0.4.0->llama_index) (2.5)
# Requirement already satisfied: anyio in /home/amor/anaconda3/lib/python3.11/site-packages (from httpx->llama-index-core<0.13.0,>=0.12.5->llama_index) (4.6.2.post1)
# Requirement already satisfied: certifi in /home/amor/anaconda3/lib/python3.11/site-packages (from httpx->llama-index-core<0.13.0,>=0.12.5->llama_index) (2024.2.2)
# Requirement already satisfied: httpcore==1.* in /home/amor/anaconda3/lib/python3.11/site-packages (from httpx->llama-index-core<0.13.0,>=0.12.5->llama_index) (1.0.7)
# Requirement already satisfied: idna in /home/amor/anaconda3/lib/python3.11/site-packages (from httpx->llama-index-core<0.13.0,>=0.12.5->llama_index) (3.10)
# Requirement already satisfied: sniffio in /home/amor/anaconda3/lib/python3.11/site-packages (from httpx->llama-index-core<0.13.0,>=0.12.5->llama_index) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in /home/amor/anaconda3/lib/python3.11/site-packages (from httpcore==1.*->httpx->llama-index-core<0.13.0,>=0.12.5->llama_index) (0.14.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /home/amor/anaconda3/lib/python3.11/site-packages (from openai>=1.14.0->llama-index-agent-openai<0.5.0,>=0.4.0->llama_index) (1.8.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /home/amor/anaconda3/lib/python3.11/site-packages (from openai>=1.14.0->llama-index-agent-openai<0.5.0,>=0.4.0->llama_index) (0.7.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/amor/anaconda3/lib/python3.11/site-packages (from pydantic>=2.8.0->llama-index-core<0.13.0,>=0.12.5->llama_index) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.1 in /home/amor/anaconda3/lib/python3.11/site-packages (from pydantic>=2.8.0->llama-index-core<0.13.0,>=0.12.5->llama_index) (2.27.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/amor/anaconda3/lib/python3.11/site-packages (from requests>=2.31.0->llama-index-core<0.13.0,>=0.12.5->llama_index) (2.0.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/amor/anaconda3/lib/python3.11/site-packages (from requests>=2.31.0->llama-index-core<0.13.0,>=0.12.5->llama_index) (2.0.7)
# Requirement already satisfied: greenlet!=0.4.17 in /home/amor/anaconda3/lib/python3.11/site-packages (from SQLAlchemy>=1.4.49->SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.13.0,>=0.12.5->llama_index) (3.0.1)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /home/amor/anaconda3/lib/python3.11/site-packages (from typing-inspect>=0.8.0->llama-index-core<0.13.0,>=0.12.5->llama_index) (1.0.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /home/amor/anaconda3/lib/python3.11/site-packages (from dataclasses-json->llama-index-core<0.13.0,>=0.12.5->llama_index) (3.23.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/amor/anaconda3/lib/python3.11/site-packages (from pandas->llama-index-legacy<0.10.0,>=0.9.48->llama_index) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/amor/anaconda3/lib/python3.11/site-packages (from pandas->llama-index-legacy<0.10.0,>=0.9.48->llama_index) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /home/amor/anaconda3/lib/python3.11/site-packages (from pandas->llama-index-legacy<0.10.0,>=0.9.48->llama_index) (2023.3)
# Requirement already satisfied: packaging>=17.0 in /home/amor/anaconda3/lib/python3.11/site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->llama-index-core<0.13.0,>=0.12.5->llama_index) (24.2)
# Requirement already satisfied: six>=1.5 in /home/amor/anaconda3/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas->llama-index-legacy<0.10.0,>=0.9.48->llama_index) (1.16.0)
# Collecting llama-index-utils-workflow
#   Downloading llama_index_utils_workflow-0.3.0-py3-none-any.whl.metadata (665 bytes)
# Requirement already satisfied: llama-index-core<0.13.0,>=0.12.0 in /home/amor/anaconda3/lib/python3.11/site-packages (from llama-index-utils-workflow) (0.12.5)
# Collecting pyvis<0.4.0,>=0.3.2 (from llama-index-utils-workflow)
#   Downloading pyvis-0.3.2-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: PyYAML>=6.0.1 in /home/amor/anaconda3/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-utils-workflow) (6.0.2)
# Requirement already satisfied: SQLAlchemy>=1.4.49 in /home/amor/anaconda3/lib/python3.11/site-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.13.0,>=0.12.0->llama-index-utils-workflow) (2.0.25)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.6 in /home/amor/anaconda3/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-utils-workflow) (3.9.3)
# Requirement already satisfied: dataclasses-json in /home/amor/anaconda3/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-utils-workflow) (0.6.7)
# Requirement already satisfied: deprecated>=1.2.9.3 in /home/amor/anaconda3/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-utils-workflow) (1.2.15)
# Requirement already satisfied: dirtyjson<2.0.0,>=1.0.8 in /home/amor/anaconda3/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-utils-workflow) (1.0.8)
# Requirement already satisfied: filetype<2.0.0,>=1.2.0 in /home/amor/anaconda3/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-utils-workflow) (1.2.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /home/amor/anaconda3/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-utils-workflow) (2023.10.0)
# Requirement already satisfied: httpx in /home/amor/anaconda3/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-utils-workflow) (0.27.2)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in /home/amor/anaconda3/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-utils-workflow) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in /home/amor/anaconda3/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-utils-workflow) (3.1)
# Requirement already satisfied: nltk>3.8.1 in /home/amor/anaconda3/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-utils-workflow) (3.9.1)
# Requirement already satisfied: numpy in /home/amor/anaconda3/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-utils-workflow) (1.26.4)
# Requirement already satisfied: pillow>=9.0.0 in /home/amor/anaconda3/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-utils-workflow) (9.5.0)
# Requirement already satisfied: pydantic>=2.8.0 in /home/amor/anaconda3/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-utils-workflow) (2.10.1)
# Requirement already satisfied: requests>=2.31.0 in /home/amor/anaconda3/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-utils-workflow) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.2.0 in /home/amor/anaconda3/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-utils-workflow) (8.5.0)
# Requirement already satisfied: tiktoken>=0.3.3 in /home/amor/anaconda3/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-utils-workflow) (0.8.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.66.1 in /home/amor/anaconda3/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-utils-workflow) (4.67.0)
# Requirement already satisfied: typing-extensions>=4.5.0 in /home/amor/anaconda3/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-utils-workflow) (4.12.2)
# Requirement already satisfied: typing-inspect>=0.8.0 in /home/amor/anaconda3/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-utils-workflow) (0.9.0)
# Requirement already satisfied: wrapt in /home/amor/anaconda3/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-utils-workflow) (1.14.1)
# Requirement already satisfied: ipython>=5.3.0 in /home/amor/anaconda3/lib/python3.11/site-packages (from pyvis<0.4.0,>=0.3.2->llama-index-utils-workflow) (8.20.0)
# Requirement already satisfied: jinja2>=2.9.6 in /home/amor/anaconda3/lib/python3.11/site-packages (from pyvis<0.4.0,>=0.3.2->llama-index-utils-workflow) (3.1.3)
# Collecting jsonpickle>=1.4.1 (from pyvis<0.4.0,>=0.3.2->llama-index-utils-workflow)
#   Downloading jsonpickle-4.0.1-py3-none-any.whl.metadata (8.2 kB)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/amor/anaconda3/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-utils-workflow) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in /home/amor/anaconda3/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-utils-workflow) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/amor/anaconda3/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-utils-workflow) (1.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/amor/anaconda3/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-utils-workflow) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /home/amor/anaconda3/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-utils-workflow) (1.9.3)
# Requirement already satisfied: decorator in /home/amor/anaconda3/lib/python3.11/site-packages (from ipython>=5.3.0->pyvis<0.4.0,>=0.3.2->llama-index-utils-workflow) (4.4.2)
# Requirement already satisfied: jedi>=0.16 in /home/amor/anaconda3/lib/python3.11/site-packages (from ipython>=5.3.0->pyvis<0.4.0,>=0.3.2->llama-index-utils-workflow) (0.18.1)
# Requirement already satisfied: matplotlib-inline in /home/amor/anaconda3/lib/python3.11/site-packages (from ipython>=5.3.0->pyvis<0.4.0,>=0.3.2->llama-index-utils-workflow) (0.1.6)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /home/amor/anaconda3/lib/python3.11/site-packages (from ipython>=5.3.0->pyvis<0.4.0,>=0.3.2->llama-index-utils-workflow) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in /home/amor/anaconda3/lib/python3.11/site-packages (from ipython>=5.3.0->pyvis<0.4.0,>=0.3.2->llama-index-utils-workflow) (2.15.1)
# Requirement already satisfied: stack-data in /home/amor/anaconda3/lib/python3.11/site-packages (from ipython>=5.3.0->pyvis<0.4.0,>=0.3.2->llama-index-utils-workflow) (0.2.0)
# Requirement already satisfied: traitlets>=5 in /home/amor/anaconda3/lib/python3.11/site-packages (from ipython>=5.3.0->pyvis<0.4.0,>=0.3.2->llama-index-utils-workflow) (5.7.1)
# Requirement already satisfied: pexpect>4.3 in /home/amor/anaconda3/lib/python3.11/site-packages (from ipython>=5.3.0->pyvis<0.4.0,>=0.3.2->llama-index-utils-workflow) (4.8.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/amor/anaconda3/lib/python3.11/site-packages (from jinja2>=2.9.6->pyvis<0.4.0,>=0.3.2->llama-index-utils-workflow) (2.1.3)
# Requirement already satisfied: click in /home/amor/anaconda3/lib/python3.11/site-packages (from nltk>3.8.1->llama-index-core<0.13.0,>=0.12.0->llama-index-utils-workflow) (8.1.7)
# Requirement already satisfied: joblib in /home/amor/anaconda3/lib/python3.11/site-packages (from nltk>3.8.1->llama-index-core<0.13.0,>=0.12.0->llama-index-utils-workflow) (1.2.0)
# Requirement already satisfied: regex>=2021.8.3 in /home/amor/anaconda3/lib/python3.11/site-packages (from nltk>3.8.1->llama-index-core<0.13.0,>=0.12.0->llama-index-utils-workflow) (2023.10.3)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/amor/anaconda3/lib/python3.11/site-packages (from pydantic>=2.8.0->llama-index-core<0.13.0,>=0.12.0->llama-index-utils-workflow) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.1 in /home/amor/anaconda3/lib/python3.11/site-packages (from pydantic>=2.8.0->llama-index-core<0.13.0,>=0.12.0->llama-index-utils-workflow) (2.27.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/amor/anaconda3/lib/python3.11/site-packages (from requests>=2.31.0->llama-index-core<0.13.0,>=0.12.0->llama-index-utils-workflow) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/amor/anaconda3/lib/python3.11/site-packages (from requests>=2.31.0->llama-index-core<0.13.0,>=0.12.0->llama-index-utils-workflow) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/amor/anaconda3/lib/python3.11/site-packages (from requests>=2.31.0->llama-index-core<0.13.0,>=0.12.0->llama-index-utils-workflow) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /home/amor/anaconda3/lib/python3.11/site-packages (from requests>=2.31.0->llama-index-core<0.13.0,>=0.12.0->llama-index-utils-workflow) (2024.2.2)
# Requirement already satisfied: greenlet!=0.4.17 in /home/amor/anaconda3/lib/python3.11/site-packages (from SQLAlchemy>=1.4.49->SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.13.0,>=0.12.0->llama-index-utils-workflow) (3.0.1)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /home/amor/anaconda3/lib/python3.11/site-packages (from typing-inspect>=0.8.0->llama-index-core<0.13.0,>=0.12.0->llama-index-utils-workflow) (1.0.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /home/amor/anaconda3/lib/python3.11/site-packages (from dataclasses-json->llama-index-core<0.13.0,>=0.12.0->llama-index-utils-workflow) (3.23.1)
# Requirement already satisfied: anyio in /home/amor/anaconda3/lib/python3.11/site-packages (from httpx->llama-index-core<0.13.0,>=0.12.0->llama-index-utils-workflow) (4.6.2.post1)
# Requirement already satisfied: httpcore==1.* in /home/amor/anaconda3/lib/python3.11/site-packages (from httpx->llama-index-core<0.13.0,>=0.12.0->llama-index-utils-workflow) (1.0.7)
# Requirement already satisfied: sniffio in /home/amor/anaconda3/lib/python3.11/site-packages (from httpx->llama-index-core<0.13.0,>=0.12.0->llama-index-utils-workflow) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in /home/amor/anaconda3/lib/python3.11/site-packages (from httpcore==1.*->httpx->llama-index-core<0.13.0,>=0.12.0->llama-index-utils-workflow) (0.14.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /home/amor/anaconda3/lib/python3.11/site-packages (from jedi>=0.16->ipython>=5.3.0->pyvis<0.4.0,>=0.3.2->llama-index-utils-workflow) (0.8.3)
# Requirement already satisfied: packaging>=17.0 in /home/amor/anaconda3/lib/python3.11/site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->llama-index-core<0.13.0,>=0.12.0->llama-index-utils-workflow) (24.2)
# Requirement already satisfied: ptyprocess>=0.5 in /home/amor/anaconda3/lib/python3.11/site-packages (from pexpect>4.3->ipython>=5.3.0->pyvis<0.4.0,>=0.3.2->llama-index-utils-workflow) (0.7.0)
# Requirement already satisfied: wcwidth in /home/amor/anaconda3/lib/python3.11/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=5.3.0->pyvis<0.4.0,>=0.3.2->llama-index-utils-workflow) (0.2.5)
# Requirement already satisfied: executing in /home/amor/anaconda3/lib/python3.11/site-packages (from stack-data->ipython>=5.3.0->pyvis<0.4.0,>=0.3.2->llama-index-utils-workflow) (0.8.3)
# Requirement already satisfied: asttokens in /home/amor/anaconda3/lib/python3.11/site-packages (from stack-data->ipython>=5.3.0->pyvis<0.4.0,>=0.3.2->llama-index-utils-workflow) (2.0.5)
# Requirement already satisfied: pure-eval in /home/amor/anaconda3/lib/python3.11/site-packages (from stack-data->ipython>=5.3.0->pyvis<0.4.0,>=0.3.2->llama-index-utils-workflow) (0.2.2)
# Requirement already satisfied: six in /home/amor/anaconda3/lib/python3.11/site-packages (from asttokens->stack-data->ipython>=5.3.0->pyvis<0.4.0,>=0.3.2->llama-index-utils-workflow) (1.16.0)
# Downloading llama_index_utils_workflow-0.3.0-py3-none-any.whl (2.8 kB)
# Downloading pyvis-0.3.2-py3-none-any.whl (756 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 756.0/756.0 kB 5.9 MB/s eta 0:00:006.1 MB/s eta 0:00:01
# Downloading jsonpickle-4.0.1-py3-none-any.whl (46 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.2/46.2 kB 3.1 MB/s eta 0:00:00
# Installing collected packages: jsonpickle, pyvis, llama-index-utils-workflow
# Successfully installed jsonpickle-4.0.1 llama-index-utils-workflow-0.3.0 pyvis-0.3.2
# Requirement already satisfied: llama-index-core in /home/amor/anaconda3/lib/python3.11/site-packages (0.12.5)
# Requirement already satisfied: PyYAML>=6.0.1 in /home/amor/anaconda3/lib/python3.11/site-packages (from llama-index-core) (6.0.2)
# Requirement already satisfied: SQLAlchemy>=1.4.49 in /home/amor/anaconda3/lib/python3.11/site-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core) (2.0.25)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.6 in /home/amor/anaconda3/lib/python3.11/site-packages (from llama-index-core) (3.9.3)
# Requirement already satisfied: dataclasses-json in /home/amor/anaconda3/lib/python3.11/site-packages (from llama-index-core) (0.6.7)
# Requirement already satisfied: deprecated>=1.2.9.3 in /home/amor/anaconda3/lib/python3.11/site-packages (from llama-index-core) (1.2.15)
# Requirement already satisfied: dirtyjson<2.0.0,>=1.0.8 in /home/amor/anaconda3/lib/python3.11/site-packages (from llama-index-core) (1.0.8)
# Requirement already satisfied: filetype<2.0.0,>=1.2.0 in /home/amor/anaconda3/lib/python3.11/site-packages (from llama-index-core) (1.2.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /home/amor/anaconda3/lib/python3.11/site-packages (from llama-index-core) (2023.10.0)
# Requirement already satisfied: httpx in /home/amor/anaconda3/lib/python3.11/site-packages (from llama-index-core) (0.27.2)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in /home/amor/anaconda3/lib/python3.11/site-packages (from llama-index-core) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in /home/amor/anaconda3/lib/python3.11/site-packages (from llama-index-core) (3.1)
# Requirement already satisfied: nltk>3.8.1 in /home/amor/anaconda3/lib/python3.11/site-packages (from llama-index-core) (3.9.1)
# Requirement already satisfied: numpy in /home/amor/anaconda3/lib/python3.11/site-packages (from llama-index-core) (1.26.4)
# Requirement already satisfied: pillow>=9.0.0 in /home/amor/anaconda3/lib/python3.11/site-packages (from llama-index-core) (9.5.0)
# Requirement already satisfied: pydantic>=2.8.0 in /home/amor/anaconda3/lib/python3.11/site-packages (from llama-index-core) (2.10.1)
# Requirement already satisfied: requests>=2.31.0 in /home/amor/anaconda3/lib/python3.11/site-packages (from llama-index-core) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.2.0 in /home/amor/anaconda3/lib/python3.11/site-packages (from llama-index-core) (8.5.0)
# Requirement already satisfied: tiktoken>=0.3.3 in /home/amor/anaconda3/lib/python3.11/site-packages (from llama-index-core) (0.8.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.66.1 in /home/amor/anaconda3/lib/python3.11/site-packages (from llama-index-core) (4.67.0)
# Requirement already satisfied: typing-extensions>=4.5.0 in /home/amor/anaconda3/lib/python3.11/site-packages (from llama-index-core) (4.12.2)
# Requirement already satisfied: typing-inspect>=0.8.0 in /home/amor/anaconda3/lib/python3.11/site-packages (from llama-index-core) (0.9.0)
# Requirement already satisfied: wrapt in /home/amor/anaconda3/lib/python3.11/site-packages (from llama-index-core) (1.14.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/amor/anaconda3/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in /home/amor/anaconda3/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/amor/anaconda3/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core) (1.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/amor/anaconda3/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /home/amor/anaconda3/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core) (1.9.3)
# Requirement already satisfied: click in /home/amor/anaconda3/lib/python3.11/site-packages (from nltk>3.8.1->llama-index-core) (8.1.7)
# Requirement already satisfied: joblib in /home/amor/anaconda3/lib/python3.11/site-packages (from nltk>3.8.1->llama-index-core) (1.2.0)
# Requirement already satisfied: regex>=2021.8.3 in /home/amor/anaconda3/lib/python3.11/site-packages (from nltk>3.8.1->llama-index-core) (2023.10.3)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/amor/anaconda3/lib/python3.11/site-packages (from pydantic>=2.8.0->llama-index-core) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.1 in /home/amor/anaconda3/lib/python3.11/site-packages (from pydantic>=2.8.0->llama-index-core) (2.27.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/amor/anaconda3/lib/python3.11/site-packages (from requests>=2.31.0->llama-index-core) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/amor/anaconda3/lib/python3.11/site-packages (from requests>=2.31.0->llama-index-core) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/amor/anaconda3/lib/python3.11/site-packages (from requests>=2.31.0->llama-index-core) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /home/amor/anaconda3/lib/python3.11/site-packages (from requests>=2.31.0->llama-index-core) (2024.2.2)
# Requirement already satisfied: greenlet!=0.4.17 in /home/amor/anaconda3/lib/python3.11/site-packages (from SQLAlchemy>=1.4.49->SQLAlchemy[asyncio]>=1.4.49->llama-index-core) (3.0.1)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /home/amor/anaconda3/lib/python3.11/site-packages (from typing-inspect>=0.8.0->llama-index-core) (1.0.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /home/amor/anaconda3/lib/python3.11/site-packages (from dataclasses-json->llama-index-core) (3.23.1)
# Requirement already satisfied: anyio in /home/amor/anaconda3/lib/python3.11/site-packages (from httpx->llama-index-core) (4.6.2.post1)
# Requirement already satisfied: httpcore==1.* in /home/amor/anaconda3/lib/python3.11/site-packages (from httpx->llama-index-core) (1.0.7)
# Requirement already satisfied: sniffio in /home/amor/anaconda3/lib/python3.11/site-packages (from httpx->llama-index-core) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in /home/amor/anaconda3/lib/python3.11/site-packages (from httpcore==1.*->httpx->llama-index-core) (0.14.0)
# Requirement already satisfied: packaging>=17.0 in /home/amor/anaconda3/lib/python3.11/site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->llama-index-core) (24.2)
# Collecting llama-index-retrievers-bm25
#   Downloading llama_index_retrievers_bm25-0.5.0-py3-none-any.whl.metadata (740 bytes)
# Collecting bm25s<0.3.0,>=0.2.0 (from llama-index-retrievers-bm25)
#   Downloading bm25s-0.2.5-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: llama-index-core<0.13.0,>=0.12.0 in /home/amor/anaconda3/lib/python3.11/site-packages (from llama-index-retrievers-bm25) (0.12.5)
# Collecting pystemmer<3.0.0.0,>=2.2.0.1 (from llama-index-retrievers-bm25)
#   Downloading PyStemmer-2.2.0.3-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.2 kB)
# Requirement already satisfied: scipy in /home/amor/anaconda3/lib/python3.11/site-packages (from bm25s<0.3.0,>=0.2.0->llama-index-retrievers-bm25) (1.11.4)
# Requirement already satisfied: numpy in /home/amor/anaconda3/lib/python3.11/site-packages (from bm25s<0.3.0,>=0.2.0->llama-index-retrievers-bm25) (1.26.4)
# Requirement already satisfied: PyYAML>=6.0.1 in /home/amor/anaconda3/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-retrievers-bm25) (6.0.2)
# Requirement already satisfied: SQLAlchemy>=1.4.49 in /home/amor/anaconda3/lib/python3.11/site-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.13.0,>=0.12.0->llama-index-retrievers-bm25) (2.0.25)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.6 in /home/amor/anaconda3/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-retrievers-bm25) (3.9.3)
# Requirement already satisfied: dataclasses-json in /home/amor/anaconda3/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-retrievers-bm25) (0.6.7)
# Requirement already satisfied: deprecated>=1.2.9.3 in /home/amor/anaconda3/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-retrievers-bm25) (1.2.15)
# Requirement already satisfied: dirtyjson<2.0.0,>=1.0.8 in /home/amor/anaconda3/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-retrievers-bm25) (1.0.8)
# Requirement already satisfied: filetype<2.0.0,>=1.2.0 in /home/amor/anaconda3/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-retrievers-bm25) (1.2.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /home/amor/anaconda3/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-retrievers-bm25) (2023.10.0)
# Requirement already satisfied: httpx in /home/amor/anaconda3/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-retrievers-bm25) (0.27.2)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in /home/amor/anaconda3/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-retrievers-bm25) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in /home/amor/anaconda3/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-retrievers-bm25) (3.1)
# Requirement already satisfied: nltk>3.8.1 in /home/amor/anaconda3/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-retrievers-bm25) (3.9.1)
# Requirement already satisfied: pillow>=9.0.0 in /home/amor/anaconda3/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-retrievers-bm25) (9.5.0)
# Requirement already satisfied: pydantic>=2.8.0 in /home/amor/anaconda3/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-retrievers-bm25) (2.10.1)
# Requirement already satisfied: requests>=2.31.0 in /home/amor/anaconda3/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-retrievers-bm25) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.2.0 in /home/amor/anaconda3/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-retrievers-bm25) (8.5.0)
# Requirement already satisfied: tiktoken>=0.3.3 in /home/amor/anaconda3/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-retrievers-bm25) (0.8.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.66.1 in /home/amor/anaconda3/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-retrievers-bm25) (4.67.0)
# Requirement already satisfied: typing-extensions>=4.5.0 in /home/amor/anaconda3/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-retrievers-bm25) (4.12.2)
# Requirement already satisfied: typing-inspect>=0.8.0 in /home/amor/anaconda3/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-retrievers-bm25) (0.9.0)
# Requirement already satisfied: wrapt in /home/amor/anaconda3/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-retrievers-bm25) (1.14.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/amor/anaconda3/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-retrievers-bm25) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in /home/amor/anaconda3/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-retrievers-bm25) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/amor/anaconda3/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-retrievers-bm25) (1.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/amor/anaconda3/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-retrievers-bm25) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /home/amor/anaconda3/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-retrievers-bm25) (1.9.3)
# Requirement already satisfied: click in /home/amor/anaconda3/lib/python3.11/site-packages (from nltk>3.8.1->llama-index-core<0.13.0,>=0.12.0->llama-index-retrievers-bm25) (8.1.7)
# Requirement already satisfied: joblib in /home/amor/anaconda3/lib/python3.11/site-packages (from nltk>3.8.1->llama-index-core<0.13.0,>=0.12.0->llama-index-retrievers-bm25) (1.2.0)
# Requirement already satisfied: regex>=2021.8.3 in /home/amor/anaconda3/lib/python3.11/site-packages (from nltk>3.8.1->llama-index-core<0.13.0,>=0.12.0->llama-index-retrievers-bm25) (2023.10.3)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/amor/anaconda3/lib/python3.11/site-packages (from pydantic>=2.8.0->llama-index-core<0.13.0,>=0.12.0->llama-index-retrievers-bm25) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.1 in /home/amor/anaconda3/lib/python3.11/site-packages (from pydantic>=2.8.0->llama-index-core<0.13.0,>=0.12.0->llama-index-retrievers-bm25) (2.27.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/amor/anaconda3/lib/python3.11/site-packages (from requests>=2.31.0->llama-index-core<0.13.0,>=0.12.0->llama-index-retrievers-bm25) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/amor/anaconda3/lib/python3.11/site-packages (from requests>=2.31.0->llama-index-core<0.13.0,>=0.12.0->llama-index-retrievers-bm25) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/amor/anaconda3/lib/python3.11/site-packages (from requests>=2.31.0->llama-index-core<0.13.0,>=0.12.0->llama-index-retrievers-bm25) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /home/amor/anaconda3/lib/python3.11/site-packages (from requests>=2.31.0->llama-index-core<0.13.0,>=0.12.0->llama-index-retrievers-bm25) (2024.2.2)
# Requirement already satisfied: greenlet!=0.4.17 in /home/amor/anaconda3/lib/python3.11/site-packages (from SQLAlchemy>=1.4.49->SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.13.0,>=0.12.0->llama-index-retrievers-bm25) (3.0.1)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /home/amor/anaconda3/lib/python3.11/site-packages (from typing-inspect>=0.8.0->llama-index-core<0.13.0,>=0.12.0->llama-index-retrievers-bm25) (1.0.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /home/amor/anaconda3/lib/python3.11/site-packages (from dataclasses-json->llama-index-core<0.13.0,>=0.12.0->llama-index-retrievers-bm25) (3.23.1)
# Requirement already satisfied: anyio in /home/amor/anaconda3/lib/python3.11/site-packages (from httpx->llama-index-core<0.13.0,>=0.12.0->llama-index-retrievers-bm25) (4.6.2.post1)
# Requirement already satisfied: httpcore==1.* in /home/amor/anaconda3/lib/python3.11/site-packages (from httpx->llama-index-core<0.13.0,>=0.12.0->llama-index-retrievers-bm25) (1.0.7)
# Requirement already satisfied: sniffio in /home/amor/anaconda3/lib/python3.11/site-packages (from httpx->llama-index-core<0.13.0,>=0.12.0->llama-index-retrievers-bm25) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in /home/amor/anaconda3/lib/python3.11/site-packages (from httpcore==1.*->httpx->llama-index-core<0.13.0,>=0.12.0->llama-index-retrievers-bm25) (0.14.0)
# Requirement already satisfied: packaging>=17.0 in /home/amor/anaconda3/lib/python3.11/site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->llama-index-core<0.13.0,>=0.12.0->llama-index-retrievers-bm25) (24.2)
# Downloading llama_index_retrievers_bm25-0.5.0-py3-none-any.whl (3.6 kB)
# Downloading bm25s-0.2.5-py3-none-any.whl (52 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.8/52.8 kB 4.1 MB/s eta 0:00:00
# Downloading PyStemmer-2.2.0.3-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (669 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 669.3/669.3 kB 3.9 MB/s eta 0:00:003.7 MB/s eta 0:00:01
# Installing collected packages: pystemmer, bm25s, llama-index-retrievers-bm25
# Successfully installed bm25s-0.2.5 llama-index-retrievers-bm25-0.5.0 pystemmer-2.2.0.3

# %%
import sys
import os 
import nest_asyncio

# Sanity check
print(sys.executable)
nest_asyncio.apply()

from dotenv import load_dotenv
load_dotenv()
# Out:
# /home/amor/anaconda3/bin/python

# %%
import os
from pydantic import BaseModel, Field
from llama_index.core.workflow import (
    Workflow,
    step,
    Event,
    Context,
    StartEvent,
    StopEvent
)
from llama_index.llms.openai import OpenAI
from llama_index.core import SimpleDirectoryReader
from llama_index.core import (
    SimpleDirectoryReader,
    load_index_from_storage,
    VectorStoreIndex,
    StorageContext,
)
from llama_index.core.node_parser import SentenceSplitter
from llama_index.retrievers.bm25 import BM25Retriever
import Stemmer
from llama_index.core import VectorStoreIndex, get_response_synthesizer
from llama_index.core.retrievers import VectorIndexRetriever
from llama_index.core.query_engine import RetrieverQueryEngine
from llama_index.core.postprocessor import LLMRerank
from llama_index.core.evaluation import FaithfulnessEvaluator

# %% [markdown]
# ## We implement the following [paper](https://arxiv.org/pdf/2403.12173) TNT LLM
#
# The goal is to do topic discovery automatically.
#
# We will focus on the taxonomy creation step.
#
#
#
#
# ![step image](data:image/jpg;base64,...)
